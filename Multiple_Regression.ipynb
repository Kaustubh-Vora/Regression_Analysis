# %% [markdown]
# # Importing libraries

# %%
# %load Multiple-Linear.py
# Importing libraries
# -------------------
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importing the dataset

# %%
#Importing a dataset
dataset = pd.read_csv('Multiple-Linear-Dataset.csv')
#Extracting independent & dependent variables
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 4].values

# %%
dataset.head()
# Out:
#    Product_1  Product_2  Product_3 Location     Profit
# 0  165349.20  136897.80  471784.10   City_1  192261.83
# 1  162597.70  151377.59  443898.53   City_2  191792.06
# 2  153441.51  101145.55  407934.54   City_3  191050.39
# 3  144372.41  118671.85  383199.62   City_1  182901.99
# 4  142107.34   91391.77  366168.42   City_3  166187.94

# %% [markdown]
# # Encoding categorical data

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#Initiating labelEncoder
labelencoder_X = LabelEncoder()
X[:, 3] = labelencoder_X.fit_transform(X[:, 3])
onehotencoder = OneHotEncoder()
X = onehotencoder.fit_transform(X).toarray()

# %% [markdown]
# # Avoiding the Dummy Variable Trap

# %%
#Dropping one of the columns created when the categorical variables were converted to dummy variables by one-hot encoding.
X = X[:, 1:]

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
#Using train_test_split for extracting training and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# # Fitting Multiple Linear Regression to the Training set

# %%
from sklearn.linear_model import LinearRegression
#Initiating Linear regression object
regressor= LinearRegression()
#Fitting Data
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting the Test set results

# %%
#Predicting data using test set
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([110421.259933  ,  99635.0731779 , 110421.259933  , 110421.259933  ,
#        110421.259933  , 119829.39601805, 119829.39601805, 119829.39601805,
#        110421.259933  , 110421.259933  ])

# %% [markdown]
# # Building the optimal model using Backward Elimination

# %%
import statsmodels.api as sm
X = np.append(arr=np.ones((50, 1)).astype(int), values=X, axis=1)
X_opt = X[:, [0, 1, 2, 3, 4, 5]]
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.203
# Model:                            OLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     2.244
# Date:                Sat, 10 Feb 2024   Prob (F-statistic):             0.0665
# Time:                        05:40:09   Log-Likelihood:                -594.98
# No. Observations:                  50   AIC:                             1202.
# Df Residuals:                      44   BIC:                             1213.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.178e+05   5659.867     20.808      0.000    1.06e+05    1.29e+05
# ...

# %%
X_opt = X[:, [0, 1, 3, 4, 5]]
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     2.286
# Date:                Sat, 10 Feb 2024   Prob (F-statistic):             0.0747
# Time:                        05:40:09   Log-Likelihood:                -596.03
# No. Observations:                  50   AIC:                             1202.
# Df Residuals:                      45   BIC:                             1212.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.166e+05   5653.397     20.628      0.000    1.05e+05    1.28e+05
# ...

# %%
X_opt = X[:, [0, 3, 4, 5]]
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     1.486
# Date:                Sat, 10 Feb 2024   Prob (F-statistic):              0.231
# Time:                        05:40:09   Log-Likelihood:                -598.34
# No. Observations:                  50   AIC:                             1205.
# Df Residuals:                      46   BIC:                             1212.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.149e+05   5793.703     19.831      0.000    1.03e+05    1.27e+05
# ...

# %%
X_opt = X[:, [0, 3, 5]]
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     1.588
# Date:                Sat, 10 Feb 2024   Prob (F-statistic):              0.215
# Time:                        05:40:09   Log-Likelihood:                -599.02
# No. Observations:                  50   AIC:                             1204.
# Df Residuals:                      47   BIC:                             1210.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        1.14e+05   5749.145     19.821      0.000    1.02e+05    1.26e+05
# ...

# %%
X_opt = X[:, [0, 3]]
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     2.532
# Date:                Sat, 10 Feb 2024   Prob (F-statistic):              0.118
# Time:                        05:40:09   Log-Likelihood:                -599.37
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.133e+05   5670.069     19.980      0.000    1.02e+05    1.25e+05
# ...

# %%
X_opt = X[:, [2, 3, 4, 5]]
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.026
# Model:                            OLS   Adj. R-squared (uncentered):             -0.059
# Method:                 Least Squares   F-statistic:                             0.3027
# Date:                Sat, 10 Feb 2024   Prob (F-statistic):                       0.875
# Time:                        05:40:09   Log-Likelihood:                         -654.60
# No. Observations:                  50   AIC:                                      1317.
# Df Residuals:                      46   BIC:                                      1325.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X = dataset[['Product_1', 'Product_3']].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)

regressor_OLS = sm.OLS(endog=y_train, exog=X_train).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.954
# Model:                            OLS   Adj. R-squared (uncentered):              0.952
# Method:                 Least Squares   F-statistic:                              395.3
# Date:                Sat, 10 Feb 2024   Prob (F-statistic):                    3.69e-26
# Time:                        05:40:09   Log-Likelihood:                         -461.80
# No. Observations:                  40   AIC:                                      927.6
# Df Residuals:                      38   BIC:                                      931.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
